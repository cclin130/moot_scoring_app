# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### load csv's with team information and all the scores

# %%
df_teams = pd.read_csv('sample_data//teams.csv')
df_scores = pd.read_csv('sample_data//scores.csv')

df_teams.head()
# Out:
#    teamID  competitorID competitor_name competitor_school
# 0       1             1               a                 x
# 1       1             2               b                 x
# 2       2             3               c                xx
# 3       2             4               d                xx
# 4       3             5               e               xxx

# %%
df_scores.head()
# Out:
#    competitorID  judgeID  score_raw
# 0             1        1        305
# 1             1        2        333
# 2             1        3        328
# 3             1        4        366
# 4             1        5        335

# %% [markdown]
# ### get each judge's average and standard deviation scores

# %%
#judge averages for each judge
df_judge_avgs = df_scores.groupby('judgeID')\
                    .mean()\
                    .reset_index()\
                    .drop('competitorID', axis=1)
df_judge_avgs.columns = ['judgeID', 'judge_avg']

df_judge_avgs.head(10)
# Out:
#    judgeID   judge_avg
# 0        1  370.166667
# 1        2  353.857143
# 2        3  339.833333
# 3        4  368.800000
# 4        5  347.800000
# 5        6  337.000000

# %%
#overall judge average
avg_score = df_scores['score_raw'].mean()

print(avg_score)
# Out:
# 353.0882352941176

# %%
#judge standard deviations
df_judge_stds = df_scores.groupby('judgeID')\
                    .std()\
                    .reset_index()\
                    .drop('competitorID', axis=1)
df_judge_stds.columns = ['judgeID', 'judge_std']

df_judge_stds.head(10)
# Out:
#    judgeID  judge_std
# 0        1  33.090281
# 1        2  23.807762
# 2        3  35.085135
# 3        4  22.840753
# 4        5  35.926313
# 5        6  36.565011

# %%
#overall judge standard deviation
std_score = df_scores['score_raw'].std()

print(std_score)
# Out:
# 31.672918981228168

# %% [markdown]
# ### get z-score for each entry in df_scores (i.e. standardize all scores), then calculate final scores

# %%
#merge both lists
df_scores_new = df_scores.merge(df_judge_avgs, on='judgeID', how='left')\
                    .merge(df_judge_stds, on='judgeID', how='left')
df_scores_new
# Out:
#     competitorID  judgeID  score_raw   judge_avg  judge_std
# 0              1        1        305  370.166667  33.090281
# 1              1        2        333  353.857143  23.807762
# 2              1        3        328  339.833333  35.085135
# 3              1        4        366  368.800000  22.840753
# 4              1        5        335  347.800000  35.926313
# 5              1        6        302  337.000000  36.565011
# 6              1        1        376  370.166667  33.090281
# 7              1        2        361  353.857143  23.807762
# 8              2        3        361  339.833333  35.085135
# 9              2        4        331  368.800000  22.840753
# 10             2        5        371  347.800000  35.926313
# 11             2        6        382  337.000000  36.565011
# 12             2        1        397  370.166667  33.090281
# 13             2        2        377  353.857143  23.807762
# 14             2        3        397  339.833333  35.085135
# 15             2        4        390  368.800000  22.840753
# 16             3        5        396  347.800000  35.926313
# 17             3        6        300  337.000000  36.565011
# 18             3        2        314  353.857143  23.807762
# 19             3        1        372  370.166667  33.090281
# 20             3        2        349  353.857143  23.807762
# 21             3        3        308  339.833333  35.085135
# 22             3        4        381  368.800000  22.840753
# 23             3        5        333  347.800000  35.926313
# 24             3        6        364  337.000000  36.565011
# 25             3        1        385  370.166667  33.090281
# 26             4        2        363  353.857143  23.807762
# 27             4        3        341  339.833333  35.085135
# 28             4        4        376  368.800000  22.840753
# 29             4        5        304  347.800000  35.926313
# 30             4        6        337  337.000000  36.565011
# 31             4        1        386  370.166667  33.090281
# 32             4        2        380  353.857143  23.807762
# 33             4        3        304  339.833333  35.085135

# %%
#calculate z-score of each entry based on judge's respective average and standard deviation scores
df_scores_new.loc[:, 'score_zscore'] = (df_scores_new.loc[:, 'score_raw'] - df_scores_new.loc[:, 'judge_avg'])/df_scores_new.loc[:, 'judge_std']

#convert each z-score to a final score
df_scores_new.loc[:,'score_final'] = df_scores_new.loc[:, 'score_zscore']*std_score + avg_score

df_scores_new
# Out:
#     competitorID  judgeID  score_raw   judge_avg  judge_std  score_zscore  \
# 0              1        1        305  370.166667  33.090281     -1.969360
# 1              1        2        333  353.857143  23.807762     -0.876065
# 2              1        3        328  339.833333  35.085135     -0.337275
# 3              1        4        366  368.800000  22.840753     -0.122588
# 4              1        5        335  347.800000  35.926313     -0.356285
# 5              1        6        302  337.000000  36.565011     -0.957199
# 6              1        1        376  370.166667  33.090281      0.176285
# 7              1        2        361  353.857143  23.807762      0.300022
# 8              2        3        361  339.833333  35.085135      0.603294
# 9              2        4        331  368.800000  22.840753     -1.654937
# 10             2        5        371  347.800000  35.926313      0.645766
# 11             2        6        382  337.000000  36.565011      1.230685
# 12             2        1        397  370.166667  33.090281      0.810913
# 13             2        2        377  353.857143  23.807762      0.972072
# 14             2        3        397  339.833333  35.085135      1.629370
# 15             2        4        390  368.800000  22.840753      0.928166
# 16             3        5        396  347.800000  35.926313      1.341635
# 17             3        6        300  337.000000  36.565011     -1.011896
# 18             3        2        314  353.857143  23.807762     -1.674124
# 19             3        1        372  370.166667  33.090281      0.055404
# 20             3        2        349  353.857143  23.807762     -0.204015
# 21             3        3        308  339.833333  35.085135     -0.907317
# 22             3        4        381  368.800000  22.840753      0.534133
# 23             3        5        333  347.800000  35.926313     -0.411954
# 24             3        6        364  337.000000  36.565011      0.738411
# 25             3        1        385  370.166667  33.090281      0.448269
# 26             4        2        363  353.857143  23.807762      0.384028
# 27             4        3        341  339.833333  35.085135      0.033252
# 28             4        4        376  368.800000  22.840753      0.315226
# 29             4        5        304  347.800000  35.926313     -1.219162
# 30             4        6        337  337.000000  36.565011      0.000000
# 31             4        1        386  370.166667  33.090281      0.478489
# 32             4        2        380  353.857143  23.807762      1.098081
# 33             4        3        304  339.833333  35.085135     -1.021325
#
#     score_final
# 0    290.712863
# 1    325.340705
# 2    342.405756
# 3    349.205519
# 4    341.803655
# 5    322.770942
# 6    358.671708
# 7    362.590814
# 8    372.196331
# 9    300.671560
# 10   373.541537
# 11   392.067613
# 12   378.772212
# 13   383.876591
# 14   404.695140
# 15   382.485947
# 16   395.581732
# 17   321.038525
# 18   300.063845
# 19   354.843041
# 20   346.626482
# 21   324.350863
# 22   370.005787
# 23   340.040440
# 24   376.475862
# 25   367.286210
# 26   365.251536
# 27   354.141437
# 28   363.072364
# 29   314.473813
# 30   353.088235
# 31   368.243377
# 32   387.867674
# 33   320.739884

# %% [markdown]
# ### using transformed scores, get individual and team rankings

# %%
# get individual rankings
df_participant_scores = df_scores_new.groupby('competitorID').mean()\
                            .reset_index()\
                            .drop(['judgeID', 'judge_avg','judge_std', 'score_zscore'], axis=1)\

df_participant_scores.head()
# Out:
#    competitorID  score_raw  score_final
# 0             1    338.250   336.687745
# 1             2    375.750   373.538366
# 2             3    350.200   349.631279
# 3             4    348.875   353.359790

# %%
#reformat individual rankings table, with participant names
df_participant_scores_final = df_participant_scores.merge(df_teams, on='competitorID', how='left')\
                                    [[ 'competitorID', 'competitor_name', 'competitor_school','score_raw', 'score_final']]\
                                    .sort_values('score_final', ascending=False)

df_participant_scores_final
# Out:
#    competitorID competitor_name competitor_school  score_raw  score_final
# 1             2               b                 x    375.750   373.538366
# 3             4               d                xx    348.875   353.359790
# 2             3               c                xx    350.200   349.631279
# 0             1               a                 x    338.250   336.687745

# %%
# get team rankings
df_team_scores = df_scores_new.drop(['judgeID','judge_avg','judge_std', 'score_zscore'], axis=1)\
                    .merge(df_teams, on='competitorID', how='left')\
                    .groupby('teamID').mean()\
                    .reset_index()\
                    .drop('competitorID', axis=1)

df_team_scores.head()
# Out:
#    teamID   score_raw  score_final
# 0       1  357.000000   355.113056
# 1       2  349.611111   351.288395

# %%
#reformat df_teams for easier merging later on
df_teams2 = df_teams.drop_duplicates('teamID').merge(df_teams, on='teamID', how='left', suffixes=('_1', '_2'))
df_teams2 = df_teams2.loc[df_teams2['competitorID_1'] != df_teams2['competitorID_2'], :]\
                .reset_index(drop=True)\
                .drop(['competitor_school_1'], axis=1)\
                .rename(columns={'competitor_school_2':'competitor_school'})

df_teams2.head()
# Out:
#    teamID  competitorID_1 competitor_name_1  competitorID_2 competitor_name_2  \
# 0       1               1                 a               2                 b
# 1       2               3                 c               4                 d
# 2       3               5                 e               6                 f
# 3       4               7                 g               8                 h
# 4       5               9                 i              10                 j
#
#   competitor_school
# 0                 x
# 1                xx
# 2               xxx
# 3                 x
# 4                xx

# %%
df_team_scores_final = df_team_scores.merge(df_teams2, on='teamID', how='left')\
                        [['teamID', 'competitorID_1', 'competitor_name_1', 'competitorID_2', 'competitor_name_2',\
                          'competitor_school', 'score_raw', 'score_final']]\
                        .sort_values('score_final', ascending=False)

df_team_scores_final
# Out:
#    teamID  competitorID_1 competitor_name_1  competitorID_2 competitor_name_2  \
# 0       1               1                 a               2                 b
# 1       2               3                 c               4                 d
#
#   competitor_school   score_raw  score_final
# 0                 x  357.000000   355.113056
# 1                xx  349.611111   351.288395

# %% [markdown]
# ### output all dataframes to csv's

# %%
df_scores_new.to_csv('output//scores_full.csv')
df_participant_scores_final.to_csv('output//scores_individual_{}.csv'.format(timestamp))
df_team_scores_final.to_csv('output//scores_team_{}.csv'.format(timestamp))
# Out:
# output//scores_full_2018-12-21_19:37.csv

# %%
timestamp = now.strftime("%Y-%m-%d_%H:%M")
'output//scores_full_{0}{1}'.format(timestamp, '.csv')
# Out:
# 'output//scores_full_2018-12-21_19:27.csv'
